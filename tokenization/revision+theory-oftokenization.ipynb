# %% [markdown]
# ## revision of tokenization

# %% [markdown]
# <h1>Tokenization means splitting text into meaningful parts so that computers can process and analyze language.

# %%
corpus = '''Pichai Sundararajan (born June 10, 1972), better known as Sundar Pichai (pronounced: /ˈsʊndɜːr pɪˈtʃeɪ/),
is an Indian–American business executive who has been the CEO of Google since 2015 and the CEO of its parent company Alphabet
Inc. since 2019.[4]
Pichai began his career as a materials engineer. Following a short stint at the management consulting firm McKinsey & Co., Pichai joined Google in 2004,[4] where he led the product management and innovation efforts for a suite of Google's client software products, including Google Chrome and ChromeOS, as well as being largely responsible for Google Drive. In addition, he went on to oversee the development of other applications such as Gmail and Google Maps.
As of February 2026, his net worth is estimated at US$1.6 billion.'''

# %%
print(corpus)
# Out:
# Pichai Sundararajan (born June 10, 1972), better known as Sundar Pichai (pronounced: /ˈsʊndɜːr pɪˈtʃeɪ/),
# is an Indian–American business executive who has been the CEO of Google since 2015 and the CEO of its parent company Alphabet
# Inc. since 2019.[4]
# Pichai began his career as a materials engineer. Following a short stint at the management consulting firm McKinsey & Co., Pichai joined Google in 2004,[4] where he led the product management and innovation efforts for a suite of Google's client software products, including Google Chrome and ChromeOS, as well as being largely responsible for Google Drive. In addition, he went on to oversee the development of other applications such as Gmail and Google Maps.
# As of February 2026, his net worth is estimated at US$1.6 billion.

# %% [markdown]
# ## SENT-tokenize

# %% [markdown]
# <h1>It's use to convert the big paragraph into a indivisual sentences</h1>
# <h1>it ues punkt sentence tokenization</h1>
# <p>Sentence tokenization is the process of splitting text into sentences using punctuation marks and language rules.
# Common sentence boundaries:
# <li>Period (.)</li>
# <li>Question mark (?)</li>
# <li>
#
# Exclamation mark (!)
# </li></p>

# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize

# %% [markdown]
# document = sent_tokenize(corpus)

# %%
document
# Out:
# ['Pichai Sundararajan (born June 10, 1972), better known as Sundar Pichai (pronounced: /ˈsʊndɜːr pɪˈtʃeɪ/),\nis an Indian–American business executive who has been the CEO of Google since 2015 and the CEO of its parent company Alphabet\nInc. since 2019.',
#  '[4]\nPichai began his career as a materials engineer.',
#  "Following a short stint at the management consulting firm McKinsey & Co., Pichai joined Google in 2004,[4] where he led the product management and innovation efforts for a suite of Google's client software products, including Google Chrome and ChromeOS, as well as being largely responsible for Google Drive.",
#  'In addition, he went on to oversee the development of other applications such as Gmail and Google Maps.',
#  'As of February 2026, his net worth is estimated at US$1.6 billion.']

# %%
len(document)
# Out:
# 5

# %% [markdown]
# ## Word-tokenize

# %% [markdown]
# <p> Word tokenization is the process of breaking text into separate words or tokens using spaces, punctuation, and language rules.<\p>
# <li>it split on based of grammer</li>

# %%
from nltk.tokenize import word_tokenize
token = word_tokenize(corpus)

# %%
print(token)
# Out:
# ['Pichai', 'Sundararajan', '(', 'born', 'June', '10', ',', '1972', ')', ',', 'better', 'known', 'as', 'Sundar', 'Pichai', '(', 'pronounced', ':', '/ˈsʊndɜːr', 'pɪˈtʃeɪ/', ')', ',', 'is', 'an', 'Indian–American', 'business', 'executive', 'who', 'has', 'been', 'the', 'CEO', 'of', 'Google', 'since', '2015', 'and', 'the', 'CEO', 'of', 'its', 'parent', 'company', 'Alphabet', 'Inc.', 'since', '2019', '.', '[', '4', ']', 'Pichai', 'began', 'his', 'career', 'as', 'a', 'materials', 'engineer', '.', 'Following', 'a', 'short', 'stint', 'at', 'the', 'management', 'consulting', 'firm', 'McKinsey', '&', 'Co.', ',', 'Pichai', 'joined', 'Google', 'in', '2004', ',', '[', '4', ']', 'where', 'he', 'led', 'the', 'product', 'management', 'and', 'innovation', 'efforts', 'for', 'a', 'suite', 'of', 'Google', "'s", 'client', 'software', 'products', ',', 'including', 'Google', 'Chrome', 'and', 'ChromeOS', ',', 'as', 'well', 'as', 'being', 'largely', 'responsible', 'for', 'Google', 'Drive', '.', 'In', 'additio
# ...

# %%
len(token)
# Out:
# 153

# %% [markdown]
# ## Wordpuntsent_tokenize

# %%
from nltk.tokenize import wordpunct_tokenize
token_pun = wordpunct_tokenize(corpus)

# %%
print(token_pun)
# Out:
# ['Pichai', 'Sundararajan', '(', 'born', 'June', '10', ',', '1972', '),', 'better', 'known', 'as', 'Sundar', 'Pichai', '(', 'pronounced', ':', '/', 'ˈsʊndɜːr', 'pɪˈtʃeɪ', '/),', 'is', 'an', 'Indian', '–', 'American', 'business', 'executive', 'who', 'has', 'been', 'the', 'CEO', 'of', 'Google', 'since', '2015', 'and', 'the', 'CEO', 'of', 'its', 'parent', 'company', 'Alphabet', 'Inc', '.', 'since', '2019', '.[', '4', ']', 'Pichai', 'began', 'his', 'career', 'as', 'a', 'materials', 'engineer', '.', 'Following', 'a', 'short', 'stint', 'at', 'the', 'management', 'consulting', 'firm', 'McKinsey', '&', 'Co', '.,', 'Pichai', 'joined', 'Google', 'in', '2004', ',[', '4', ']', 'where', 'he', 'led', 'the', 'product', 'management', 'and', 'innovation', 'efforts', 'for', 'a', 'suite', 'of', 'Google', "'", 's', 'client', 'software', 'products', ',', 'including', 'Google', 'Chrome', 'and', 'ChromeOS', ',', 'as', 'well', 'as', 'being', 'largely', 'responsible', 'for', 'Google', 'Drive', '.', 'In', 'add
# ...

# %%
len(token_pun)
# Out:
# 156

# %% [markdown]
# ## Treebankword-tokenize

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenize = TreebankWordTokenizer()
tokens = tokenize.tokenize(corpus)

# %%
print(token)
# Out:
# ['Pichai', 'Sundararajan', '(', 'born', 'June', '10', ',', '1972', ')', ',', 'better', 'known', 'as', 'Sundar', 'Pichai', '(', 'pronounced', ':', '/ˈsʊndɜːr', 'pɪˈtʃeɪ/', ')', ',', 'is', 'an', 'Indian–American', 'business', 'executive', 'who', 'has', 'been', 'the', 'CEO', 'of', 'Google', 'since', '2015', 'and', 'the', 'CEO', 'of', 'its', 'parent', 'company', 'Alphabet', 'Inc.', 'since', '2019', '.', '[', '4', ']', 'Pichai', 'began', 'his', 'career', 'as', 'a', 'materials', 'engineer', '.', 'Following', 'a', 'short', 'stint', 'at', 'the', 'management', 'consulting', 'firm', 'McKinsey', '&', 'Co.', ',', 'Pichai', 'joined', 'Google', 'in', '2004', ',', '[', '4', ']', 'where', 'he', 'led', 'the', 'product', 'management', 'and', 'innovation', 'efforts', 'for', 'a', 'suite', 'of', 'Google', "'s", 'client', 'software', 'products', ',', 'including', 'Google', 'Chrome', 'and', 'ChromeOS', ',', 'as', 'well', 'as', 'being', 'largely', 'responsible', 'for', 'Google', 'Drive', '.', 'In', 'additio
# ...

# %%
len(tokens)
# Out:
# 149
