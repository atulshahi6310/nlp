# %%
corpus = '''Understanding this dynamic helps engineers optimize attention mechanisms in frameworks like TensorFlow or PyTorch. By forcing the model to allocate its computational power primarily to "key tokens," it prevents the system from losing track of the core logic over a long sequence.
(Note: "Token theory" can occasionally refer to "Token Identity Theory" in the philosophy of mind, or a "Token Economy" in behavioral psychology. If you meant one of those instead, just let me know!)'''

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)
print(documents)
# Out:
# ['Understanding this dynamic helps engineers optimize attention mechanisms in frameworks like TensorFlow or PyTorch.', 'By forcing the model to allocate its computational power primarily to "key tokens," it prevents the system from losing track of the core logic over a long sequence.', '(Note: "Token theory" can occasionally refer to "Token Identity Theory" in the philosophy of mind, or a "Token Economy" in behavioral psychology.', 'If you meant one of those instead, just let me know!)']

# %%
count = 0
for sent in documents:
    print(sent)
    count += 1
# Out:
# Understanding this dynamic helps engineers optimize attention mechanisms in frameworks like TensorFlow or PyTorch.
# By forcing the model to allocate its computational power primarily to "key tokens," it prevents the system from losing track of the core logic over a long sequence.
# (Note: "Token theory" can occasionally refer to "Token Identity Theory" in the philosophy of mind, or a "Token Economy" in behavioral psychology.
# If you meant one of those instead, just let me know!)

# %%
print(count)
# Out:
# 4

# %% [markdown]
# ## Result of the corpus
# <p>there are 4 sent means we have the 4 tockens from the courpus</p>

# %%
## tokenization
###  courpus ----> words
### documents ----> words
count_token = 0
from nltk.tokenize import word_tokenize
words = word_tokenize(corpus)
# Out:
# ['Understanding', 'this', 'dynamic', 'helps', 'engineers', 'optimize', 'attention', 'mechanisms', 'in', 'frameworks', 'like', 'TensorFlow', 'or', 'PyTorch', '.', 'By', 'forcing', 'the', 'model', 'to', 'allocate', 'its', 'computational', 'power', 'primarily', 'to', '``', 'key', 'tokens', ',', "''", 'it', 'prevents', 'the', 'system', 'from', 'losing', 'track', 'of', 'the', 'core', 'logic', 'over', 'a', 'long', 'sequence', '.', '(', 'Note', ':', '``', 'Token', 'theory', "''", 'can', 'occasionally', 'refer', 'to', '``', 'Token', 'Identity', 'Theory', "''", 'in', 'the', 'philosophy', 'of', 'mind', ',', 'or', 'a', '``', 'Token', 'Economy', "''", 'in', 'behavioral', 'psychology', '.', 'If', 'you', 'meant', 'one', 'of', 'those', 'instead', ',', 'just', 'let', 'me', 'know', '!', ')']

# %%
for words in
