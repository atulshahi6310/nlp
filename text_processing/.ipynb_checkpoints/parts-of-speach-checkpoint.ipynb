# %% [markdown]
# ## Stopwords

# %%
corpus ='''Pichai Sundararajan (born June 10, 1972), better known as Sundar Pichai (pronounced: /ˈsʊndɜːr pɪˈtʃeɪ/),
is an Indian–American business executive who has been the CEO of Google since 2015 and the CEO of its parent company Alphabet Inc.
since 2019.
Pichai began his career as a materials engineer. Following a short stint at the management consulting firm McKinsey & Co., Pichai joined Google in 2004,[4] where he led the product management and innovation efforts for a suite of Google's client software products, including Google Chrome and ChromeOS, as well as being largely responsible for Google Drive. In addition, he went on to oversee the development of other applications such as Gmail and Google Maps.
As of February 2026, his net worth is estimated at US$1.6 billion
'''

# %% [markdown]
# # Word tokenizer

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(corpus)

# %%
print(tokens)
# Out:
# ['Pichai', 'Sundararajan', '(', 'born', 'June', '10', ',', '1972', ')', ',', 'better', 'known', 'as', 'Sundar', 'Pichai', '(', 'pronounced', ':', '/ˈsʊndɜːr', 'pɪˈtʃeɪ/', ')', ',', 'is', 'an', 'Indian–American', 'business', 'executive', 'who', 'has', 'been', 'the', 'CEO', 'of', 'Google', 'since', '2015', 'and', 'the', 'CEO', 'of', 'its', 'parent', 'company', 'Alphabet', 'Inc.', 'since', '2019', '.', 'Pichai', 'began', 'his', 'career', 'as', 'a', 'materials', 'engineer', '.', 'Following', 'a', 'short', 'stint', 'at', 'the', 'management', 'consulting', 'firm', 'McKinsey', '&', 'Co.', ',', 'Pichai', 'joined', 'Google', 'in', '2004', ',', '[', '4', ']', 'where', 'he', 'led', 'the', 'product', 'management', 'and', 'innovation', 'efforts', 'for', 'a', 'suite', 'of', 'Google', "'s", 'client', 'software', 'products', ',', 'including', 'Google', 'Chrome', 'and', 'ChromeOS', ',', 'as', 'well', 'as', 'being', 'largely', 'responsible', 'for', 'Google', 'Drive', '.', 'In', 'addition', ',', 'he', 'went', 'on', 'to', 'oversee', 'the', 'development', 'of', 'other', 'applications', 'such', 'as', 'Gmail', 'and', 'Google', 'Maps', '.', 'As', 'of', 'February', '2026', ',', 'his', 'net', 'worth', 'is', 'estimated', 'at', 'US', '$', '1.6', 'billion']

# %%
from nltk.corpus import stopwords
stopword = stopwords.words("english")

# %%
from nltk.stem import WordNetLemmatizer
Lemmatizer = WordNetLemmatizer()
token =[Lemmatizer.lemmatize(words) for words in tokens if words not in stopword]

# %%
print(token)
# Out:
# ['Pichai', 'Sundararajan', '(', 'born', 'June', '10', ',', '1972', ')', ',', 'better', 'known', 'Sundar', 'Pichai', '(', 'pronounced', ':', '/ˈsʊndɜːr', 'pɪˈtʃeɪ/', ')', ',', 'Indian–American', 'business', 'executive', 'CEO', 'Google', 'since', '2015', 'CEO', 'parent', 'company', 'Alphabet', 'Inc.', 'since', '2019', '.', 'Pichai', 'began', 'career', 'material', 'engineer', '.', 'Following', 'short', 'stint', 'management', 'consulting', 'firm', 'McKinsey', '&', 'Co.', ',', 'Pichai', 'joined', 'Google', '2004', ',', '[', '4', ']', 'led', 'product', 'management', 'innovation', 'effort', 'suite', 'Google', "'s", 'client', 'software', 'product', ',', 'including', 'Google', 'Chrome', 'ChromeOS', ',', 'well', 'largely', 'responsible', 'Google', 'Drive', '.', 'In', 'addition', ',', 'went', 'oversee', 'development', 'application', 'Gmail', 'Google', 'Maps', '.', 'As', 'February', '2026', ',', 'net', 'worth', 'estimated', 'US', '$', '1.6', 'billion']

# %%
len(token)
# Out:
# 105

# %%
len(tokens)
# Out:
# 149

# %%
sentence = [' '.join(token)]

# %%
sentence
# Out:
# ["Pichai Sundararajan ( born June 10 , 1972 ) , better known Sundar Pichai ( pronounced : /ˈsʊndɜːr pɪˈtʃeɪ/ ) , Indian–American business executive CEO Google since 2015 CEO parent company Alphabet Inc. since 2019 . Pichai began career material engineer . Following short stint management consulting firm McKinsey & Co. , Pichai joined Google 2004 , [ 4 ] led product management innovation effort suite Google 's client software product , including Google Chrome ChromeOS , well largely responsible Google Drive . In addition , went oversee development application Gmail Google Maps . As February 2026 , net worth estimated US $ 1.6 billion"]
